# %%
from tensorflow import keras
import joblib

# Cargar el modelo

modelo = keras.models.load_model("modelo_final_optimizado.h5", compile=False)

# Cargar el scaler
scaler_X = joblib.load("scaler_X_final.pkl")   # o el nombre exacto que guardaste
scaler_y = joblib.load("scaler_y_final.pkl")
